# %% [markdown]
# 7.4

# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5

# %%
things[1] = things[1].capitalize()
print(things)
#capitalizes the second entry in things
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.6

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.7

# %%
things.remove("salmonella")
print(things)
print("Nobel Prize for me!!")
# Out:
# ['MOZZARELLA', 'Cinderella']
# Nobel Prize for me!!

# %% [markdown]
# 9.1

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2

# %%
def get_odds():
    for num in range(10):
        if num % 2 == 1:
            yield num
            
count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        break
# Out:
# 5
