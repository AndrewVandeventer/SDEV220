# %% [markdown]
# 16.8 Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 16.4. As in 16.6, select and print the title column from the book table in alphabetical order.

# %%
import sqlite3

conn = sqlite3.connect('book.db')

with open('book.sql', 'r') as f:
    sql_script = f.read()
    
conn.executescript(sql_script)
conn.commit()
conn.close()

print("Database 'book.sql' has been created and initialized successfully.")
# Out:
# Database 'book.sql' has been created and initialized successfully.

# %% [markdown]
# Above we used Sqlite to create book.db and execute instructions from book.sql. Below, we will use the new database to complete the problem.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///book.db')

# %% [markdown]
# this cell connected us to the the database, now we will use sql tools to query it

# %%
from sqlalchemy import text
with engine.connect() as conn:
    result = conn.execute(text("SELECT title FROM book ORDER BY title"))
    for row in result:
        print(row)
# Out:
# ('Perdido Street Station',)
# ('Perdido Street Station',)
# ('Perdido Street Station',)
# ('Perdido Street Station',)
# ('Perdido Street Station',)
# ('Perdido Street Station',)
# ('Small Gods',)
# ('Small Gods',)
# ('Small Gods',)
# ('Small Gods',)
# ('Small Gods',)
# ('Small Gods',)
# ('The Spellman Files',)
# ('The Spellman Files',)
# ('The Spellman Files',)
# ('The Spellman Files',)
# ('The Spellman Files',)
# ('The Spellman Files',)
# ('The Weirdstone of Brisingamen',)
# ('The Weirdstone of Brisingamen',)
# ('The Weirdstone of Brisingamen',)
# ('The Weirdstone of Brisingamen',)
# ('The Weirdstone of Brisingamen',)
# ('The Weirdstone of Brisingamen',)
# ('Thud!',)
# ('Thud!',)
# ('Thud!',)
# ('Thud!',)
# ('Thud!',)
# ('Thud!',)
